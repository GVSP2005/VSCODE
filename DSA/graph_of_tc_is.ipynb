# %%
import matplotlib.pyplot as plt

# %%
x=[]
for i in range(100):
    x.append((i+1)*1000)

# %%
y_const=[0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.008000,0.000000,0.000000,0.000000,0.000000,0.000000]
y_ascend=[0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.002000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.010000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.003000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000,0.000000]
y_random=[0.000000,0.007000,0.008000,0.016000,0.010000,0.032000,0.051000,0.067000,0.066000,0.100000,0.099000,0.134000,0.167000,0.157000,0.198000,0.244000,0.269000,0.284000,0.330000,0.351000,0.375000,0.418000,0.451000,0.494000,0.517000,0.587000,0.608000,0.687000,0.726000,0.782000,0.816000,0.873000,0.927000,0.983000,1.042000,1.117000,1.174000,1.258000,1.320000,1.416000,1.461000,1.668000,1.728000,1.860000,1.946000,2.095000,1.997000,2.209000,2.041000,2.138000,2.215000,2.399000,2.664000,5.573000,7.592000,8.644000,5.619000,3.301000,3.470000,3.580000,3.680000,3.817000,3.752000,3.931000,4.091000,3.952000,4.282000,4.604000,4.505000,4.531000,4.684000,4.890000,4.572000,4.681000,4.749000,4.951000,4.943000,5.388000,5.582000,5.676000,5.576000,5.720000,5.842000,6.013000,6.178000,6.271000,6.442000,6.768000,6.698000,6.995000,7.027000,7.213000,7.356000,7.492000,7.588000,7.849000,7.853000,8.184000,8.303000,8.436000]
y_descend=[0.000000,0.012000,0.016000,0.032000,0.034000,0.069000,0.093000,0.119000,0.136000,0.211000,0.233000,0.276000,0.322000,0.377000,0.416000,0.471000,0.525000,0.617000,0.658000,0.757000,0.806000,0.904000,0.990000,1.083000,1.073000,1.184000,1.237000,1.329000,1.455000,1.574000,1.632000,1.763000,1.884000,1.976000,2.084000,2.223000,2.376000,2.519000,2.666000,2.744000,2.881000,2.987000,3.239000,3.312000,3.501000,3.610000,3.820000,3.939000,4.115000,4.272000,4.439000,4.638000,4.781000,4.989000,5.198000,5.330000,6.037000,5.754000,5.999000,6.175000,6.352000,6.787000,6.808000,6.988000,7.221000,7.717000,7.702000,7.940000,8.166000,8.395000,8.648000,8.840000,9.406000,10.179000,9.894000,10.432000,10.317000,10.387000,10.804000,11.017000,11.244000,11.612000,12.093000,12.242000,12.632000,181.192000,15.246000,14.135000,14.181000,14.400000,14.886000,15.115000,15.644000,15.732000,16.162000,16.403000,16.902000,17.843000,19.069000,17.743000]

# %%
plt.plot(x,y_const,label='Constant ')
plt.plot(x,y_ascend,label='Ascending')
plt.plot(x,y_random,label='Random')
plt.plot(x,y_descend,label='Descending')
plt.legend()
plt.show()
